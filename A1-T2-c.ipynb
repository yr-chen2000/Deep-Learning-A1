# %%
from __future__ import print_function
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Input, Conv2D, MaxPooling2D
from keras import backend as K
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Load Data
images = np.load('data/images.npy')
labels = np.load('data/labels.npy')

#Shuffle
indices = np.arange(images.shape[0])
np.random.shuffle(indices)
images = images[indices]
labels = labels[indices]
# input image dimensions
img_rows, img_cols = images.shape[1], images.shape[2]

if K.image_data_format() == 'channels_first':
    images = images.reshape(images.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    images = images.reshape(images.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

images = images.astype('float32')
images /= 255

#80/10/10% splits for training/validation and test sets
train_images, temp_images, train_labels, temp_labels = train_test_split(images, labels, test_size=0.2)
val_images, test_images, val_labels, test_labels = train_test_split(temp_images, temp_labels, test_size=0.5)

# %%
#“common sense” accuracy
def common_sense_accuracy(predicted, actual):

    pred_minutes = predicted[0]*60+predicted[1]
    actual_minutes = actual[0]*60+actual[1]

    abs_diff = abs(pred_minutes-actual_minutes)
    
    return min(abs_diff, 12*60-abs_diff)

# %%
def re_category(labels):
    # Minutes transformation to sine and cosine (radians: 0 to 2π)
    minute_angle = labels[:][1] * (2 * np.pi / 60)
    minute_sin = np.sin(minute_angle)
    minute_cos = np.cos(minute_angle)

    transformed_labels = np.vstack((minute_sin, minute_cos)).T
    return transformed_labels

train_h_labels = np.array([h[0] for h in train_labels])
val_h_labels= np.array([h[0] for h in val_labels])
test_h_labels = np.array([h[0] for h in test_labels])
train_min_labels = np.array([re_category(h) for h in train_labels])
val_min_labels= np.array([re_category(h) for h in val_labels])
test_min_labels = np.array([re_category(h) for h in test_labels])

# %%
batch_size = 32
epochs = 30
# Build Model
input_ = Input(shape=(img_rows, img_cols, 1))

x = Conv2D(32, kernel_size=(3, 3),
                 activation='relu')(input_)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.1)(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.1)(x)
x = Conv2D(256, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.1)(x)
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.1)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.1)(x)

# Output
hours_output = Dense(12, activation='softmax', name='hours_output')(x)
minutes_output = Dense(2, activation='tanh', name='minutes_output')(x)


model = Model(inputs=[input_], outputs=[hours_output, minutes_output])
model.compile(loss={'hours_output':keras.losses.sparse_categorical_crossentropy, 'minutes_output': 'mean_squared_error'},
              optimizer=keras.optimizers.Adam(learning_rate=1e-4),
              metrics={'hours_output': 'accuracy', 'minutes_output': 'mae'})

# Fit Model
history = model.fit(train_images, {'hours_output': train_h_labels, 'minutes_output': train_min_labels},
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(val_images, {'hours_output': val_h_labels, 'minutes_output': val_min_labels}))

df = pd.DataFrame(history.history)
df.plot(figsize=(8, 5))
plt.grid(True)
# plt.gca().set_ylim(0, 1)
plt.show()
# Evaluate Model
score = model.evaluate(val_images, {'hours_output': val_h_labels, 'minutes_output': val_min_labels}, verbose=0)
print('Validation hours_output_loss:', score[2])
print('Validation minutes_output_loss:', score[3])
score_final = model.evaluate(test_images, {'hours_output': test_h_labels, 'minutes_output': test_min_labels}, verbose=0)
print('Test hours_output_loss:', score_final[2])
print('Test minutes_output_loss:', score_final[3])
# Out:
# 2024-11-13 22:24:54.877025: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2024-11-13 22:24:54.877072: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-11-13 22:24:54.877093: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-11-13 22:24:54.877117: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-11-13 22:24:54.877132: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/30
# /Users/chenyiru/miniconda3/envs/IDL/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor']. Received: the structure of inputs=*
#   warnings.warn(
# 2024-11-13 22:24:56.595786: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - hours_output_accuracy: 0.0788 - hours_output_loss: 2.4869 - loss: 2.9884 - minutes_output_loss: 0.5014 - minutes_output_mae: 0.6382 - val_hours_output_accuracy: 0.0800 - val_hours_output_loss: 2.4851 - val_loss: 2.9851 - val_minutes_output_loss: 0.5000 - val_minutes_output_mae: 0.6366
# Epoch 2/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 32s 72ms/step - hours_output_accuracy: 0.0800 - hours_output_loss: 2.4850 - loss: 2.9851 - minutes_output_loss: 0.5001 - minutes_output_mae: 0.6363 - val_hours_output_accuracy: 0.0756 - val_hours_output_loss: 2.4851 - val_loss: 2.9851 - val_minutes_output_loss: 0.5000 - val_minutes_output_mae: 0.6365
# Epoch 3/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 46s 103ms/step - hours_output_accuracy: 0.0834 - hours_output_loss: 2.4848 - loss: 2.9850 - minutes_output_loss: 0.5001 - minutes_output_mae: 0.6360 - val_hours_output_accuracy: 0.0800 - val_hours_output_loss: 2.4833 - val_loss: 2.9833 - val_minutes_output_loss: 0.5000 - val_minutes_output_mae: 0.6365
# Epoch 4/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - hours_output_accuracy: 0.1092 - hours_output_loss: 2.4407 - loss: 2.9460 - minutes_output_loss: 0.5052 - minutes_output_mae: 0.6381 - val_hours_output_accuracy: 0.2000 - val_hours_output_loss: 2.1169 - val_loss: 2.6227 - val_minutes_output_loss: 0.5094 - val_minutes_output_mae: 0.6393
# Epoch 5/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - hours_output_accuracy: 0.2477 - hours_output_loss: 2.0139 - loss: 2.5635 - minutes_output_loss: 0.5495 - minutes_output_mae: 0.6528 - val_hours_output_accuracy: 0.3656 - val_hours_output_loss: 1.7015 - val_loss: 2.2127 - val_minutes_output_loss: 0.5145 - val_minutes_output_mae: 0.6408
# Epoch 6/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 56s 124ms/step - hours_output_accuracy: 0.3732 - hours_output_loss: 1.6280 - loss: 2.2009 - minutes_output_loss: 0.5729 - minutes_output_mae: 0.6601 - val_hours_output_accuracy: 0.4867 - val_hours_output_loss: 1.3437 - val_loss: 1.8574 - val_minutes_output_loss: 0.5176 - val_minutes_output_mae: 0.6423
# Epoch 7/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - hours_output_accuracy: 0.4676 - hours_output_loss: 1.3406 - loss: 1.9260 - minutes_output_loss: 0.5854 - minutes_output_mae: 0.6640 - val_hours_output_accuracy: 0.5983 - val_hours_output_loss: 1.1296 - val_loss: 1.6442 - val_minutes_output_loss: 0.5173 - val_minutes_output_mae: 0.6420
# Epoch 8/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - hours_output_accuracy: 0.5574 - hours_output_loss: 1.1298 - loss: 1.7218 - minutes_output_loss: 0.5920 - minutes_output_mae: 0.6666 - val_hours_output_accuracy: 0.6922 - val_hours_output_loss: 0.9076 - val_loss: 1.4276 - val_minutes_output_loss: 0.5231 - val_minutes_output_mae: 0.6441
# Epoch 9/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 125ms/step - hours_output_accuracy: 0.6285 - hours_output_loss: 0.9529 - loss: 1.5508 - minutes_output_loss: 0.5980 - minutes_output_mae: 0.6683 - val_hours_output_accuracy: 0.7356 - val_hours_output_loss: 0.7783 - val_loss: 1.2989 - val_minutes_output_loss: 0.5213 - val_minutes_output_mae: 0.6438
# Epoch 10/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - hours_output_accuracy: 0.6769 - hours_output_loss: 0.8331 - loss: 1.4280 - minutes_output_loss: 0.5949 - minutes_output_mae: 0.6672 - val_hours_output_accuracy: 0.7817 - val_hours_output_loss: 0.6835 - val_loss: 1.2007 - val_minutes_output_loss: 0.5176 - val_minutes_output_mae: 0.6424
# Epoch 11/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - hours_output_accuracy: 0.7180 - hours_output_loss: 0.7301 - loss: 1.3197 - minutes_output_loss: 0.5896 - minutes_output_mae: 0.6649 - val_hours_output_accuracy: 0.8056 - val_hours_output_loss: 0.6069 - val_loss: 1.1233 - val_minutes_output_loss: 0.5163 - val_minutes_output_mae: 0.6416
# Epoch 12/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - hours_output_accuracy: 0.7506 - hours_output_loss: 0.6614 - loss: 1.2455 - minutes_output_loss: 0.5841 - minutes_output_mae: 0.6636 - val_hours_output_accuracy: 0.8233 - val_hours_output_loss: 0.5574 - val_loss: 1.0713 - val_minutes_output_loss: 0.5141 - val_minutes_output_mae: 0.6412
# Epoch 13/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 56s 125ms/step - hours_output_accuracy: 0.7783 - hours_output_loss: 0.5934 - loss: 1.1709 - minutes_output_loss: 0.5775 - minutes_output_mae: 0.6618 - val_hours_output_accuracy: 0.8328 - val_hours_output_loss: 0.4835 - val_loss: 0.9965 - val_minutes_output_loss: 0.5148 - val_minutes_output_mae: 0.6414
# Epoch 14/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - hours_output_accuracy: 0.8014 - hours_output_loss: 0.5308 - loss: 1.1012 - minutes_output_loss: 0.5704 - minutes_output_mae: 0.6589 - val_hours_output_accuracy: 0.8583 - val_hours_output_loss: 0.4504 - val_loss: 0.9609 - val_minutes_output_loss: 0.5114 - val_minutes_output_mae: 0.6404
# Epoch 15/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - hours_output_accuracy: 0.8195 - hours_output_loss: 0.4770 - loss: 1.0418 - minutes_output_loss: 0.5649 - minutes_output_mae: 0.6576 - val_hours_output_accuracy: 0.8756 - val_hours_output_loss: 0.4008 - val_loss: 0.9107 - val_minutes_output_loss: 0.5110 - val_minutes_output_mae: 0.6402
# Epoch 16/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - hours_output_accuracy: 0.8378 - hours_output_loss: 0.4366 - loss: 0.9939 - minutes_output_loss: 0.5573 - minutes_output_mae: 0.6545 - val_hours_output_accuracy: 0.8878 - val_hours_output_loss: 0.3523 - val_loss: 0.8613 - val_minutes_output_loss: 0.5086 - val_minutes_output_mae: 0.6392
# Epoch 17/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 56s 125ms/step - hours_output_accuracy: 0.8526 - hours_output_loss: 0.3962 - loss: 0.9462 - minutes_output_loss: 0.5500 - minutes_output_mae: 0.6526 - val_hours_output_accuracy: 0.8694 - val_hours_output_loss: 0.3514 - val_loss: 0.8618 - val_minutes_output_loss: 0.5094 - val_minutes_output_mae: 0.6392
# Epoch 18/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 56s 125ms/step - hours_output_accuracy: 0.8592 - hours_output_loss: 0.3724 - loss: 0.9157 - minutes_output_loss: 0.5433 - minutes_output_mae: 0.6509 - val_hours_output_accuracy: 0.8944 - val_hours_output_loss: 0.3058 - val_loss: 0.8130 - val_minutes_output_loss: 0.5072 - val_minutes_output_mae: 0.6392
# Epoch 19/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - hours_output_accuracy: 0.8732 - hours_output_loss: 0.3460 - loss: 0.8826 - minutes_output_loss: 0.5366 - minutes_output_mae: 0.6488 - val_hours_output_accuracy: 0.8928 - val_hours_output_loss: 0.3260 - val_loss: 0.8311 - val_minutes_output_loss: 0.5056 - val_minutes_output_mae: 0.6383
# Epoch 20/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - hours_output_accuracy: 0.8862 - hours_output_loss: 0.3079 - loss: 0.8360 - minutes_output_loss: 0.5281 - minutes_output_mae: 0.6453 - val_hours_output_accuracy: 0.9150 - val_hours_output_loss: 0.2877 - val_loss: 0.7930 - val_minutes_output_loss: 0.5045 - val_minutes_output_mae: 0.6384
# Epoch 21/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - hours_output_accuracy: 0.8957 - hours_output_loss: 0.2840 - loss: 0.8086 - minutes_output_loss: 0.5246 - minutes_output_mae: 0.6448 - val_hours_output_accuracy: 0.9128 - val_hours_output_loss: 0.2604 - val_loss: 0.7657 - val_minutes_output_loss: 0.5048 - val_minutes_output_mae: 0.6382
# Epoch 22/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - hours_output_accuracy: 0.8999 - hours_output_loss: 0.2708 - loss: 0.7901 - minutes_output_loss: 0.5192 - minutes_output_mae: 0.6425 - val_hours_output_accuracy: 0.9150 - val_hours_output_loss: 0.2485 - val_loss: 0.7515 - val_minutes_output_loss: 0.5031 - val_minutes_output_mae: 0.6377
# Epoch 23/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - hours_output_accuracy: 0.9016 - hours_output_loss: 0.2664 - loss: 0.7811 - minutes_output_loss: 0.5147 - minutes_output_mae: 0.6417 - val_hours_output_accuracy: 0.9144 - val_hours_output_loss: 0.2484 - val_loss: 0.7500 - val_minutes_output_loss: 0.5025 - val_minutes_output_mae: 0.6379
# Epoch 24/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 55s 122ms/step - hours_output_accuracy: 0.9135 - hours_output_loss: 0.2448 - loss: 0.7561 - minutes_output_loss: 0.5114 - minutes_output_mae: 0.6399 - val_hours_output_accuracy: 0.9089 - val_hours_output_loss: 0.2515 - val_loss: 0.7542 - val_minutes_output_loss: 0.5017 - val_minutes_output_mae: 0.6375
# Epoch 25/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 43s 95ms/step - hours_output_accuracy: 0.9189 - hours_output_loss: 0.2300 - loss: 0.7383 - minutes_output_loss: 0.5083 - minutes_output_mae: 0.6386 - val_hours_output_accuracy: 0.9189 - val_hours_output_loss: 0.2336 - val_loss: 0.7326 - val_minutes_output_loss: 0.5011 - val_minutes_output_mae: 0.6372
# Epoch 26/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 42s 93ms/step - hours_output_accuracy: 0.9220 - hours_output_loss: 0.2138 - loss: 0.7198 - minutes_output_loss: 0.5061 - minutes_output_mae: 0.6384 - val_hours_output_accuracy: 0.9078 - val_hours_output_loss: 0.2653 - val_loss: 0.7681 - val_minutes_output_loss: 0.5008 - val_minutes_output_mae: 0.6371
# Epoch 27/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 53s 119ms/step - hours_output_accuracy: 0.9205 - hours_output_loss: 0.2206 - loss: 0.7251 - minutes_output_loss: 0.5045 - minutes_output_mae: 0.6382 - val_hours_output_accuracy: 0.9133 - val_hours_output_loss: 0.2437 - val_loss: 0.7465 - val_minutes_output_loss: 0.5018 - val_minutes_output_mae: 0.6375
# Epoch 28/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - hours_output_accuracy: 0.9266 - hours_output_loss: 0.1997 - loss: 0.7036 - minutes_output_loss: 0.5039 - minutes_output_mae: 0.6381 - val_hours_output_accuracy: 0.9294 - val_hours_output_loss: 0.2130 - val_loss: 0.7141 - val_minutes_output_loss: 0.5004 - val_minutes_output_mae: 0.6370
# Epoch 29/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 55s 123ms/step - hours_output_accuracy: 0.9313 - hours_output_loss: 0.1860 - loss: 0.6893 - minutes_output_loss: 0.5033 - minutes_output_mae: 0.6370 - val_hours_output_accuracy: 0.9167 - val_hours_output_loss: 0.2331 - val_loss: 0.7336 - val_minutes_output_loss: 0.5004 - val_minutes_output_mae: 0.6367
# Epoch 30/30
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 54s 120ms/step - hours_output_accuracy: 0.9387 - hours_output_loss: 0.1802 - loss: 0.6822 - minutes_output_loss: 0.5020 - minutes_output_mae: 0.6372 - val_hours_output_accuracy: 0.9217 - val_hours_output_loss: 0.2085 - val_loss: 0.7118 - val_minutes_output_loss: 0.5016 - val_minutes_output_mae: 0.6375
# Validation hours_output_loss: 0.5015932321548462
# Validation minutes_output_loss: 0.92166668176651
# Test hours_output_loss: 0.502438485622406
# Test minutes_output_loss: 0.9227777719497681

# %%
def calculate_time_from_predictions(predictions):
    minute_sin, minute_cos = predictions[:, 0], predictions[:, 1]

    # Calculate angles for minutes
    minute_angle = np.arctan2(minute_sin, minute_cos)

    # Convert angles back to minute values
    minute = ((minute_angle % (2 * np.pi)) * (60 / (2 * np.pi))).astype(int)

    return minute

# %%
predictions = model.predict(test_images)
predicted_hours = np.argmax(predictions[0], axis=1)
predicted_minutes = calculate_time_from_predictions(predictions[1])

common_sense_errors = [common_sense_accuracy([predicted_hours[i], predicted_minutes[i]], test_labels[i]) 
                       for i in range(len(test_labels))]
print('Average common sense error:', np.mean(common_sense_errors))
# Out:
# /Users/chenyiru/miniconda3/envs/IDL/lib/python3.10/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor']. Received: the structure of inputs=*
#   warnings.warn(
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# Average common sense error: 22.27777777777778

# %%
# Plot a sample of clock images
plt.figure(figsize=(12, 12))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(test_images[i], cmap='gray')
    plt.title(f'Predict: {predicted_hours[i]}:{predicted_minutes[i]:02d},Label: {test_labels[i][0]}:{test_labels[i][1]:02d}')
    plt.axis('off')
plt.show()
