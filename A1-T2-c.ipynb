# %%
from __future__ import print_function
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D
from keras import backend as K
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# 2024-11-10 23:53:46.985414: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#Load Data
images = np.load('data/images.npy')
labels = np.load('data/labels.npy')

#Shuffle
indices = np.arange(images.shape[0])
np.random.shuffle(indices)
images = images[indices]
labels = labels[indices]
# input image dimensions
img_rows, img_cols = images.shape[1], images.shape[2]

if K.image_data_format() == 'channels_first':
    images = images.reshape(images.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    images = images.reshape(images.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

images = images.astype('float32')
images /= 255

#80/10/10% splits for training/validation and test sets
train_images, temp_images, train_labels, temp_labels = train_test_split(images, labels, test_size=0.2)
val_images, test_images, val_labels, test_labels = train_test_split(temp_images, temp_labels, test_size=0.5)

# %%
#“common sense” accuracy
def common_sense_accuracy(predicted, actual):

    pred_minutes = predicted[0]*60+predicted[1]
    actual_minutes = actual[0]*60+actual[1]

    abs_diff = abs(pred_minutes-actual_minutes)
    
    return min(abs_diff, 12*60-abs_diff)

# %%
batch_size = 32
epochs = 20
def re_category(labels):
    # Minutes transformation to sine and cosine (radians: 0 to 2π)
    minute_angle = labels[:][1] * (2 * np.pi / 60)
    minute_sin = np.sin(minute_angle)
    minute_cos = np.cos(minute_angle)

    transformed_labels = np.vstack((minute_sin, minute_cos)).T
    return transformed_labels

train_h_labels = np.array([h[0] for h in train_labels])
val_h_labels= np.array([h[0] for h in val_labels])
test_h_labels = np.array([h[0] for h in test_labels])
train_min_labels = np.array([re_category(h) for h in train_labels])
val_min_labels= np.array([re_category(h) for h in val_labels])
test_min_labels = np.array([re_category(h) for h in test_labels])

# %%
# Build Model
input_ = Input(shape=(img_rows, img_cols, 1))

x = Conv2D(32, kernel_size=(3, 3),
                 activation='relu')(input_)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.1)(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.1)(x)
x = Conv2D(256, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.1)(x)
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.1)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.1)(x)

# Output
hours_output = Dense(12, activation='softmax', name='hours_output')(x)
minutes_output = Dense(2, activation='tanh', name='minutes_output')(x)


model = Model(inputs=[input_], outputs=[hours_output, minutes_output])
model.compile(loss={'hours_output':keras.losses.sparse_categorical_crossentropy, 'minutes_output': 'mean_squared_error'},
              optimizer=keras.optimizers.Adam(learning_rate=1e-4),
              metrics={'hours_output': 'accuracy', 'minutes_output': 'mae'})

# Fit Model
model.fit(train_images, {'hours_output': train_h_labels, 'minutes_output': train_min_labels},
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(val_images, {'hours_output': val_h_labels, 'minutes_output': val_min_labels}))

# Evaluate Model
score = model.evaluate(val_images, {'hours_output': val_h_labels, 'minutes_output': val_min_labels}, verbose=0)
print('Test loss:', score[0])
print('Test hour accuracy:', score[1])
print('Test minute MAE:', score[2])
score = model.evaluate(test_images, {'hours_output': test_h_labels, 'minutes_output': test_min_labels}, verbose=0)
print('Test loss:', score[0])
print('Test hour accuracy:', score[1])
print('Test minute MAE:', score[2])
# Out:
# Epoch 1/20
# 2024-11-10 23:53:51.829469: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 324000000 exceeds 10% of free system memory.
# /home/yiru/miniconda3/envs/IDL/lib/python3.12/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor']. Received: the structure of inputs=*
#   warnings.warn(
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 130s 285ms/step - hours_output_accuracy: 0.0781 - hours_output_loss: 2.4865 - loss: 2.9882 - minutes_output_loss: 0.5016 - minutes_output_mae: 0.6378 - val_hours_output_accuracy: 0.0744 - val_hours_output_loss: 2.4851 - val_loss: 2.9851 - val_minutes_output_loss: 0.5001 - val_minutes_output_mae: 0.6364
# Epoch 2/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 119s 264ms/step - hours_output_accuracy: 0.0789 - hours_output_loss: 2.4849 - loss: 2.9850 - minutes_output_loss: 0.5001 - minutes_output_mae: 0.6368 - val_hours_output_accuracy: 0.0772 - val_hours_output_loss: 2.4851 - val_loss: 2.9852 - val_minutes_output_loss: 0.5001 - val_minutes_output_mae: 0.6365
# Epoch 3/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 117s 260ms/step - hours_output_accuracy: 0.0813 - hours_output_loss: 2.4850 - loss: 2.9850 - minutes_output_loss: 0.5000 - minutes_output_mae: 0.6364 - val_hours_output_accuracy: 0.0800 - val_hours_output_loss: 2.4852 - val_loss: 2.9851 - val_minutes_output_loss: 0.4999 - val_minutes_output_mae: 0.6363
# Epoch 4/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 116s 257ms/step - hours_output_accuracy: 0.0859 - hours_output_loss: 2.4841 - loss: 2.9843 - minutes_output_loss: 0.5001 - minutes_output_mae: 0.6361 - val_hours_output_accuracy: 0.1228 - val_hours_output_loss: 2.3976 - val_loss: 2.9033 - val_minutes_output_loss: 0.5070 - val_minutes_output_mae: 0.6404
# Epoch 5/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 117s 260ms/step - hours_output_accuracy: 0.1670 - hours_output_loss: 2.2855 - loss: 2.8115 - minutes_output_loss: 0.5261 - minutes_output_mae: 0.6447 - val_hours_output_accuracy: 0.2683 - val_hours_output_loss: 1.8928 - val_loss: 2.4099 - val_minutes_output_loss: 0.5175 - val_minutes_output_mae: 0.6422
# Epoch 6/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 124s 276ms/step - hours_output_accuracy: 0.3046 - hours_output_loss: 1.8224 - loss: 2.3898 - minutes_output_loss: 0.5674 - minutes_output_mae: 0.6576 - val_hours_output_accuracy: 0.4506 - val_hours_output_loss: 1.4409 - val_loss: 1.9690 - val_minutes_output_loss: 0.5289 - val_minutes_output_mae: 0.6459
# Epoch 7/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 121s 268ms/step - hours_output_accuracy: 0.4433 - hours_output_loss: 1.4264 - loss: 2.0186 - minutes_output_loss: 0.5922 - minutes_output_mae: 0.6663 - val_hours_output_accuracy: 0.6078 - val_hours_output_loss: 1.1170 - val_loss: 1.6386 - val_minutes_output_loss: 0.5219 - val_minutes_output_mae: 0.6443
# Epoch 8/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 121s 269ms/step - hours_output_accuracy: 0.5586 - hours_output_loss: 1.1430 - loss: 1.7469 - minutes_output_loss: 0.6039 - minutes_output_mae: 0.6700 - val_hours_output_accuracy: 0.6883 - val_hours_output_loss: 0.9000 - val_loss: 1.4261 - val_minutes_output_loss: 0.5266 - val_minutes_output_mae: 0.6447
# Epoch 9/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 113s 251ms/step - hours_output_accuracy: 0.6311 - hours_output_loss: 0.9480 - loss: 1.5592 - minutes_output_loss: 0.6112 - minutes_output_mae: 0.6730 - val_hours_output_accuracy: 0.7539 - val_hours_output_loss: 0.7752 - val_loss: 1.2974 - val_minutes_output_loss: 0.5226 - val_minutes_output_mae: 0.6444
# Epoch 10/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 118s 262ms/step - hours_output_accuracy: 0.6922 - hours_output_loss: 0.8047 - loss: 1.4150 - minutes_output_loss: 0.6103 - minutes_output_mae: 0.6720 - val_hours_output_accuracy: 0.7922 - val_hours_output_loss: 0.6555 - val_loss: 1.1778 - val_minutes_output_loss: 0.5229 - val_minutes_output_mae: 0.6440
# Epoch 11/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 116s 258ms/step - hours_output_accuracy: 0.7453 - hours_output_loss: 0.6929 - loss: 1.3032 - minutes_output_loss: 0.6103 - minutes_output_mae: 0.6725 - val_hours_output_accuracy: 0.8306 - val_hours_output_loss: 0.5422 - val_loss: 1.0705 - val_minutes_output_loss: 0.5292 - val_minutes_output_mae: 0.6467
# Epoch 12/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 114s 253ms/step - hours_output_accuracy: 0.7826 - hours_output_loss: 0.6001 - loss: 1.2050 - minutes_output_loss: 0.6049 - minutes_output_mae: 0.6706 - val_hours_output_accuracy: 0.8561 - val_hours_output_loss: 0.4765 - val_loss: 0.9989 - val_minutes_output_loss: 0.5226 - val_minutes_output_mae: 0.6450
# Epoch 13/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 114s 253ms/step - hours_output_accuracy: 0.8061 - hours_output_loss: 0.5264 - loss: 1.1263 - minutes_output_loss: 0.5999 - minutes_output_mae: 0.6690 - val_hours_output_accuracy: 0.8611 - val_hours_output_loss: 0.4333 - val_loss: 0.9535 - val_minutes_output_loss: 0.5210 - val_minutes_output_mae: 0.6447
# Epoch 14/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 114s 254ms/step - hours_output_accuracy: 0.8380 - hours_output_loss: 0.4731 - loss: 1.0666 - minutes_output_loss: 0.5935 - minutes_output_mae: 0.6675 - val_hours_output_accuracy: 0.8683 - val_hours_output_loss: 0.4100 - val_loss: 0.9275 - val_minutes_output_loss: 0.5174 - val_minutes_output_mae: 0.6428
# Epoch 15/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 113s 252ms/step - hours_output_accuracy: 0.8501 - hours_output_loss: 0.4310 - loss: 1.0173 - minutes_output_loss: 0.5863 - minutes_output_mae: 0.6645 - val_hours_output_accuracy: 0.8867 - val_hours_output_loss: 0.3617 - val_loss: 0.8783 - val_minutes_output_loss: 0.5167 - val_minutes_output_mae: 0.6425
# Epoch 16/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 115s 255ms/step - hours_output_accuracy: 0.8664 - hours_output_loss: 0.3769 - loss: 0.9563 - minutes_output_loss: 0.5794 - minutes_output_mae: 0.6629 - val_hours_output_accuracy: 0.8922 - val_hours_output_loss: 0.3385 - val_loss: 0.8554 - val_minutes_output_loss: 0.5163 - val_minutes_output_mae: 0.6431
# Epoch 17/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 113s 251ms/step - hours_output_accuracy: 0.8788 - hours_output_loss: 0.3493 - loss: 0.9208 - minutes_output_loss: 0.5715 - minutes_output_mae: 0.6604 - val_hours_output_accuracy: 0.9006 - val_hours_output_loss: 0.3166 - val_loss: 0.8284 - val_minutes_output_loss: 0.5131 - val_minutes_output_mae: 0.6419
# Epoch 18/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 113s 251ms/step - hours_output_accuracy: 0.8971 - hours_output_loss: 0.3061 - loss: 0.8699 - minutes_output_loss: 0.5638 - minutes_output_mae: 0.6573 - val_hours_output_accuracy: 0.9017 - val_hours_output_loss: 0.2925 - val_loss: 0.8035 - val_minutes_output_loss: 0.5109 - val_minutes_output_mae: 0.6411
# Epoch 19/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 113s 251ms/step - hours_output_accuracy: 0.8933 - hours_output_loss: 0.2996 - loss: 0.8546 - minutes_output_loss: 0.5550 - minutes_output_mae: 0.6544 - val_hours_output_accuracy: 0.9078 - val_hours_output_loss: 0.2726 - val_loss: 0.7893 - val_minutes_output_loss: 0.5164 - val_minutes_output_mae: 0.6427
# Epoch 20/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 114s 252ms/step - hours_output_accuracy: 0.9078 - hours_output_loss: 0.2639 - loss: 0.8122 - minutes_output_loss: 0.5484 - minutes_output_mae: 0.6518 - val_hours_output_accuracy: 0.9039 - val_hours_output_loss: 0.2626 - val_loss: 0.7749 - val_minutes_output_loss: 0.5105 - val_minutes_output_mae: 0.6412
# Test loss: 0.7748525142669678
# Test hour accuracy: 0.2626357674598694
# Test minute MAE: 0.5105019211769104
# Test loss: 0.7740873694419861
# Test hour accuracy: 0.2727528512477875
# Test minute MAE: 0.5098019242286682

# %%
def calculate_time_from_predictions(predictions):
    minute_sin, minute_cos = predictions[:, 0], predictions[:, 1]

    # Calculate angles for minutes
    minute_angle = np.arctan2(minute_sin, minute_cos)

    # Convert angles back to minute values
    minute = ((minute_angle % (2 * np.pi)) * (60 / (2 * np.pi))).astype(int)

    return minute

# %%
predictions = model.predict(test_images)
predicted_hours = np.argmax(predictions[0], axis=1)
predicted_minutes = calculate_time_from_predictions(predictions[1])
common_sense_errors = [common_sense_accuracy([pred_hour, pred_min], test)
                       for pred_hour, pred_min, test, in zip(predicted_hours, predicted_minutes, test_labels)]
print('Average common sense error:', np.mean(common_sense_errors))
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step
# Average common sense error: 22.111666666666668

# %%
# Plot a sample of clock images
plt.figure(figsize=(12, 12))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(test_images[i], cmap='gray')
    plt.title(f'Predict: {predicted_hours[i]}:{predicted_minutes[i]:02d},Label: {test_labels[i][0]}:{test_labels[i][1]:02d}')
    plt.axis('off')
plt.show()
